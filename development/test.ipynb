# %%
import pandas as pd

# %%
df_history = pd.read_csv("data/data/history-Table 1.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df_history = pd.read_csv("data/data/history-Table 1.csv")
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
# ...

# %%
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', 5000)

# %%
df_history
# Out:
#        entity_id                             area    type   status   state  \
# 0          94297              Система.Таск-трекер  Дефект  Закрыто  Normal
# 1          94297              Система.Таск-трекер  Дефект  Закрыто  Normal
# 2          94297              Система.Таск-трекер  Дефект  Закрыто  Normal
# 3          94297              Система.Таск-трекер  Дефект  Закрыто  Normal
# 4          94297              Система.Таск-трекер  Дефект  Закрыто  Normal
# ...          ...                              ...     ...      ...     ...
# 61155    5179881  Управление релизами изменениями  Задача  Закрыто  Normal
# 61156    5179881  Управление релизами изменениями  Задача  Закрыто  Normal
# 61157    5179881  Управление релизами изменениями  Задача  Закрыто  Normal
# 61158    5179881  Управление релизами изменениями  Задача  Закрыто  Normal
# 61159    5179881  Управление релизами изменениями  Задача  Закрыто  Normal
#
#       priority ticket_number  \
# 0      Средний     PPTS-1965
# ...

# %%
df_history['spent'].unique()
# Out:
# array([      nan, 3.600e+03, 1.080e+04, 7.200e+03, 5.760e+04, 1.440e+04,
#        8.640e+04, 2.880e+04, 0.000e+00, 1.152e+05, 2.520e+04, 1.440e+05,
#        4.320e+04, 1.008e+05, 2.160e+04, 6.000e+01, 2.016e+05, 7.200e+04,
#        9.360e+04, 7.920e+04, 3.960e+04, 7.560e+04, 5.040e+04, 1.296e+05,
#        3.240e+04, 3.600e+04, 2.304e+05, 1.584e+05, 1.404e+05, 1.620e+05,
#        1.728e+05, 6.480e+04, 1.260e+04, 1.800e+04, 1.512e+05, 6.120e+04,
#        2.880e+05])
